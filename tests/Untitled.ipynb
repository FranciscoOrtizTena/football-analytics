# %%
import nflreadpy as nfl
import pandas as pd
import pyarrow

# %%
player_stats = nfl.load_player_stats([2025])

# %%
df = player_stats.to_pandas()

# %%
df[df.player_name == "M.Stafford"]
# Out:
#         player_id player_name player_display_name position position_group  \
# 5      00-0026498  M.Stafford    Matthew Stafford       QB             QB
# 1076   00-0026498  M.Stafford    Matthew Stafford       QB             QB
# 2184   00-0026498  M.Stafford    Matthew Stafford       QB             QB
# 3287   00-0026498  M.Stafford    Matthew Stafford       QB             QB
# 4392   00-0026498  M.Stafford    Matthew Stafford       QB             QB
# 5355   00-0026498  M.Stafford    Matthew Stafford       QB             QB
# 6368   00-0026498  M.Stafford    Matthew Stafford       QB             QB
# 8295   00-0026498  M.Stafford    Matthew Stafford       QB             QB
# 9244   00-0026498  M.Stafford    Matthew Stafford       QB             QB
# 10207  00-0026498  M.Stafford    Matthew Stafford       QB             QB
# 11238  00-0026498  M.Stafford    Matthew Stafford       QB             QB
# 12205  00-0026498  M.Stafford    Matthew Stafford       QB             QB
# ...

# %%
for c in df[df.player_name == "M.Stafford"].columns:
    print(c)
# Out:
# player_id
# player_name
# player_display_name
# position
# position_group
# headshot_url
# season
# week
# season_type
# team
# opponent_team
# completions
# attempts
# passing_yards
# passing_tds
# passing_interceptions
# sacks_suffered
# sack_yards_lost
# sack_fumbles
# sack_fumbles_lost
# passing_air_yards
# passing_yards_after_catch
# passing_first_downs
# passing_epa
# passing_cpoe
# passing_2pt_conversions
# pacr
# carries
# rushing_yards
# rushing_tds
# rushing_fumbles
# rushing_fumbles_lost
# rushing_first_downs
# rushing_epa
# rushing_2pt_conversions
# receptions
# targets
# receiving_yards
# receiving_tds
# receiving_fumbles
# receiving_fumbles_lost
# receiving_air_yards
# receiving_yards_after_catch
# receiving_first_downs
# receiving_epa
# receiving_2pt_conversions
# racr
# target_share
# air_yards_share
# wopr
# special_teams_tds
# def_tackles_solo
# def_tackles_with_assist
# def_tackle_assists
# def_tackles_for_loss
# def_tackles_for_loss_yards
# def_fumbles_forced
# ...

# %%
df[df.player_name == "C.McCaffrey"].describe().T[90:]
# Out:
#                     count       mean       std  min   25%   50%    75%   max
# pat_made             19.0   0.000000  0.000000  0.0   0.0   0.0   0.00   0.0
# pat_att              19.0   0.000000  0.000000  0.0   0.0   0.0   0.00   0.0
# pat_missed           19.0   0.000000  0.000000  0.0   0.0   0.0   0.00   0.0
# pat_blocked          19.0   0.000000  0.000000  0.0   0.0   0.0   0.00   0.0
# pat_pct               0.0        NaN       NaN  NaN   NaN   NaN    NaN   NaN
# gwfg_made            19.0   0.000000  0.000000  0.0   0.0   0.0   0.00   0.0
# gwfg_att             19.0   0.000000  0.000000  0.0   0.0   0.0   0.00   0.0
# gwfg_missed          19.0   0.000000  0.000000  0.0   0.0   0.0   0.00   0.0
# gwfg_blocked         19.0   0.000000  0.000000  0.0   0.0   0.0   0.00   0.0
# gwfg_distance        19.0   0.000000  0.000000  0.0   0.0   0.0   0.00   0.0
# fantasy_points       19.0  18.178947  7.993510  5.7  13.7  17.1  23.75  32.1
# ...

# %%
df[df.player_name == "C.McCaffrey"].penalties
# Out:
# 96       0
# 1175     0
# 2285     0
# 3393     0
# 4479     0
# 5453     0
# 6475     0
# 7488     0
# 8388     0
# 9338     0
# 10300    0
# 11322    0
# 12303    0
# 14354    0
# 15415    0
# 16507    0
# 17566    0
# 18578    0
# 18966    0
# Name: penalties, dtype: int32
